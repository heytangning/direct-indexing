# %%
import numpy as np
import scipy.stats as st
import cvxpy as cvx
from pandas_datareader import data  as pdr #修正
import pandas as pd
from datetime import date
from dateutil.relativedelta import relativedelta
import yfinance as yf #追加

# %%
# !pip install cvxpy
# Out:
# Collecting cvxpy
#   Downloading cvxpy-1.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 747 kB/s eta 0:00:01
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.2.post8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      |████████████████████████████████| 299 kB 5.3 MB/s eta 0:00:01
# Collecting ecos>=2
#   Downloading ecos-2.0.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (221 kB)
#      |████████████████████████████████| 221 kB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: setuptools<=64.0.2 in /home/nske/miniconda3/envs/jp38/lib/python3.8/site-packages (from cvxpy) (58.0.4)
# Requirement already satisfied: scipy>=1.1.0 in /home/nske/miniconda3/envs/jp38/lib/python3.8/site-packages (from cvxpy) (1.7.1)
# Requirement already satisfied: numpy>=1.15 in /home/nske/miniconda3/envs/jp38/lib/python3.8/site-packages (from cvxpy) (1.24.1)
# Collecting scs>=1.1.6
#   Downloading scs-3.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 7.4 MB/s eta 0:00:01
# Collecting qdldl
#   Downloading qdldl-0.1.5.post3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 6.7 MB/s eta 0:00:01
# Collecting numpy>=1.15
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 8.8 MB/s eta 0:00:01
# Installing collected packages: numpy, qdldl, scs, osqp, ecos, cvxpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.22.4 which is incompatible.
# Successfully installed cvxpy-1.3.0 ecos-2.0.12 numpy-1.22.4 osqp-0.6.2.post8 qdldl-0.1.5.post3 scs-3.2.2

# %%
import pandas.io.data as web

all_data = {}
for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']:
    all_data[ticker] = web.get_data_yahoo(ticker, '1/1/2003', '1/1/2013')

price = DataFrame({tic: data['Adj Close']
                   for tic, data in all_data.iteritems()})
volume = DataFrame({tic: data['Volume']
                    for tic, data in all_data.iteritems()})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import pandas.io.data as web
#       3 all_data = {}
#       4 for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']:
#
# ModuleNotFoundError: No module named 'pandas.io.data'

# %%
from pandas_datareader import data  as pdr #修正
from datetime import date
from dateutil.relativedelta import relativedelta
import yfinance as yf #追加
yf.pdr_override() #追加

today = date.today()
ago = today - relativedelta(years=10)
data = pdr.get_data_yahoo('^N225',  ago, today) #修正
print(data)

# %%
from pandas_datareader import data  as pdr #修正
from datetime import date
from dateutil.relativedelta import relativedelta
import yfinance as yf #追加
yf.pdr_override() #追加

# %%
today = date.today()
ago = today - relativedelta(years=10)

# %%
sp500 = pdr.get_data_yahoo('^GSPC',  '2013-01-01', '2022-12-31') 
sp500.to_csv('sp500.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# https://www.liberatedstocktrader.com/sp-500-companies/ から取得したSP500の時価総額上位50社
tickers=pd.read_csv('tickers.csv')

# %%
tickers[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_859/2492994891.py in <module>
# ----> 1 tickers[0]
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
ticker = tickers.iloc[1,0]
data = pdr.get_data_yahoo(ticker,  '2013-01-01', '2022-12-31') 
# data.to_csv(ticker+'.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_859/4111546312.py in <module>
#       1 ticker = tickers.iloc[1,0]
# ----> 2 data = pdr.get_data_yahoo(ticker,  '2013-01-01', '2022-12-31')
#       3 # data.to_csv(ticker+'.csv')
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     151         try:
#     152             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154         except KeyError:
#     155             msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %%
tickers.iloc[0,0]
# Out:
# 'AAPL'

# %%
for index, row in tickers.iterrows():
    ticker = row
    data = pdr.get_data_yahoo(ticker,  '2013-01-01', '2022-12-31') 
    data.to_csv('/data/'+ticker+'.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_859/3439619676.py in <module>
#       1 for index, row in tickers.iterrows():
#       2     ticker = row
# ----> 3     data = pdr.get_data_yahoo(ticker,  '2013-01-01', '2022-12-31')
#       4     data.to_csv('/data/'+ticker+'.csv')
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/base.py in read(self)
#     256             df = self._dl_mult_symbols(self.symbols.index)
#     257         else:
# --> 258             df = self._dl_mult_symbols(self.symbols)
#     259         return df
#     260
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/base.py in _dl_mult_symbols(self, symbols)
#     266             for sym in sym_group:
#     267                 try:
# --> 268                     stocks[sym] = self._read_one_data(self.url, self._get_params(sym))
#     269                     passed.append(sym)
#     270                 except (IOError, KeyError):
#
# ~/miniconda3/envs/jp38/lib/python3.8/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     151         try:
#     152             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154         except KeyError:
#     155             msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers
