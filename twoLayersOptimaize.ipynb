# %%
import os as os
import numpy as np
import scipy.stats as st
import cvxpy as cvx
import pandas as pd
import datetime
import warnings
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
warnings.filterwarnings('ignore')


#os.chdir('C:/directindex/ver1')
# os.chdir('C:/Users/admin/Documents/directIndex/baseline')
os.chdir('C:/Users/208017/Documents/directindex/baseline')

constCnt = 60

portName = 'portfolio'+str(constCnt)


#過去指数ファンド情報読み取り
tickers=pd.read_csv('allTickers.csv')
tickers=tickers['ticker'].to_list()     #ticker列のデータ取得

#一件目のファンドの過去日付データ読み取り
data = pd.read_csv('./allData/'+tickers[0]+'.csv')
data = data.drop(['Open', 'High','Low','Close','Adj Close','Volume'], axis=1)

dataDate = data.copy()

#過去期間2013-01-02～2018-12-31のファンドの過去データ取得
for ticker in tickers:
    d = pd.read_csv('./allData/'+ticker+'.csv')
    d = d.drop(['Open', 'High','Low','Adj Close','Volume'], axis=1)
    d = d.rename(columns={'Close': ticker}) #列名称をファンド名にリネーム
    
    date1 = d.iat[0,0]
    if date1 == "2013-01-02":
        data = pd.merge(data,d,on='Date')

#日付、年、月、週というデータを取得する
cal = data[['Date']]
cal['Datetime'] = pd.to_datetime(cal['Date'])
cal['year'] = cal['Datetime'].dt.year
cal['month'] = cal['Datetime'].dt.month
cal['week'] = cal['Datetime'].dt.week

cal['mon'] = 1
for index, row in cal.iterrows():
    if index > 0 and cal.iloc[index,3] != cal.iloc[index-1,3]:
        cal.iloc[index,5] = cal.iloc[index-1,5]+1
    else:
        cal.iloc[index,5] = cal.iloc[index-1,5]
        
cal['iweek'] = 1
for index, row in cal.iterrows():
    if index > 0 and cal.iloc[index,4] != cal.iloc[index-1,4]:
        cal.iloc[index,6] = cal.iloc[index-1,6]+1
    else:
        cal.iloc[index,6] = cal.iloc[index-1,6]

#インデックス設定
data = data.set_index('Date')

# 行・列の差分・変化率を取得する
R = data.pct_change()
R = R.fillna(0)

#累積しないリターンを保存
Rd = R
R = R + 1

#累積リータン
R = R.cumprod()

#配列T：縦、N：横
T = Rd.shape[0]
N = Rd.shape[1]

#ベンチマーク情報
Benchmark = pd.read_csv('sp500.csv')
Benchmark = Benchmark.set_index('Date')
Benchmark = Benchmark.drop(['Open', 'High','Low','Adj Close','Volume'], axis=1)

#------------------------------------------------
#シミュレーション
#------------------------------------------------
di = Benchmark.copy() # ポートフォリオの時価総額の推移
Benchmarkd = Benchmark.copy()
Benchmarkd = Benchmarkd.pct_change()
Benchmarkd = Benchmarkd.fillna(0)

did = Benchmark.copy() #日次
did100 = Benchmark.copy() #日次


#最適ウェイト計算の
mon_window = 72 # 6年間72月


w_init = np.ones(N)/N
w_initd = np.ones(N)/N
# w_initm = np.ones(N)/N

N100=constCnt
w_init100 = np.ones(N100)/N100
w_initd100 = np.ones(N100)/N100

for i in range(120 - mon_window):
    start = 1
    end = i+mon_window
    
    # 計算対象の開始終了
    startdate = cal.query('mon >= '+str(start)+' and mon <= '+str(end))['Date'].min()
    enddate = cal.query('mon >= '+str(start)+' and mon <= '+str(end))['Date'].max()

    # 日次リターンで最適化
    # 各資産の計算期間分のデータを取得し計算期間初からのリターンを計算
    assetd = Rd[startdate:enddate]
    assetd = assetd.values
    
    # ベンチマークの計算期間分のデータを取得し計算期間初からのリターンを計算
    indxd = Benchmarkd[startdate:enddate]
    indxd = indxd.values
    indxd = np.squeeze(indxd)

    # 最適化ソルバでウェイトを算出
    weightd = cvx.Variable(N,value=w_initd)
    objd = cvx.Minimize(cvx.sum_squares((assetd@weightd) - indxd))
    mintracerrd = cvx.Problem(objd, [cvx.sum(weightd) == 1.0,weightd >= 0])
    mintracerrd.solve(verbose=False)
    wd = weightd.value
    
    wd[wd<0]=0
    wd=wd/wd.sum()
    w_initd = wd
    
    #--------------------------------------------------------------------
    # ウェイト上位100のファンドを判断し、再最適化ツルバでウェイトを算出
    wdSorted = sorted(wd, reverse=True)
    max100 = []
    for j in range(constCnt):
        weightValue = wdSorted[j]
        max100 = max100 + [m for m, v in enumerate(wd) if v == weightValue]
            
    tickers100 = []
    tickersList = R.columns
    for n in range(constCnt):
        indexN = max100[n]
        tickers100.append(tickersList[indexN])
    
    print(tickers100)
    
    Rd100 = Rd.copy()
    R100 = R.copy()
    for m in range(len(tickersList)):
        colName = tickersList[m]
        n = 0
        for j in range(constCnt):
            if colName == tickers100[j]:
                n = 1
        if(n==0):   
            Rd100 = Rd100.drop(colName,axis=1)
            R100 = R100.drop(colName,axis=1)

    assetd100 = Rd100[startdate:enddate]    
    assetd100 = assetd100.values
    
    weightd100 = cvx.Variable(N100,value=w_initd100)
    objd100 = cvx.Minimize(cvx.sum_squares((assetd100@weightd100) - indxd))
    mintracerrd100 = cvx.Problem(objd100, [cvx.sum(weightd100) == 1.0,weightd100 >= 0])
    mintracerrd100.solve(verbose=False)
    wd100 = weightd100.value
    
    wd100[wd100<0]=0
    wd100=wd100/wd100.sum()
    w_initd100 = wd100
    
    #----------------------------------------------------------------------
    
    # 計算したウェイトと運用期間の各資産のリターンから運用期間のポートフォリオの時価評価額の比率を計算
    dstart = cal.query('mon >= '+str(end+1)+' and mon <= '+str(end+1))['Date'].min()
    dend = cal.query('mon >= '+str(end+1)+' and mon <= '+str(end+1))['Date'].max()
    dstartm1 = cal.query('mon >= '+str(end)+' and mon <= '+str(end))['Date'].max()

    #Backtest期間
    rtmpd=R[dstartm1:dend]
        
    rtmpd = rtmpd.pct_change()
    rtmpd = rtmpd.dropna()
    rtmpd = rtmpd + 1
    rtmpd = rtmpd.cumprod()

    dd = rtmpd.values@wd
    dd = dd*did.at[dstartm1,'Close']

    dd = np.expand_dims(dd, 1)
    did[dstart:dend]=dd
    
    #--------------------------------------------------------------------
    rtmpd100=R100[dstartm1:dend]
    rtmpd100 = rtmpd100.pct_change()
    rtmpd100 = rtmpd100.dropna()
    rtmpd100 = rtmpd100 + 1
    rtmpd100 = rtmpd100.cumprod()
    dd100 = rtmpd100.values@wd100
    dd100 = dd100*did100.at[dstartm1,'Close']
    dd100 = np.expand_dims(dd100, 1)
    did100[dstart:dend]=dd100
    #----------------------------------------------------------------------

import plotly.graph_objects as go
from plotly.subplots import make_subplots
ganpon=100000
fig = make_subplots(rows=2, cols=1)


Benchmark.to_csv('b2.csv')
di.to_csv('d2.csv')

from matplotlib import dates as mdates

heights = [4, 1,1,1]
fig = plt.figure(figsize=(20, 20))
spec = fig.add_gridspec(ncols=1, nrows=4,  height_ratios=heights)
#spec = fig.add_gridspec(ncols=1, nrows=5)
ax = fig.add_subplot(spec[0, 0])

#ベンチマーク
ax.plot(pd.to_datetime(Benchmark.index),Benchmark['Close'],c='k')
#フル460銘柄
ax.plot(pd.to_datetime(did.index),did['Close'],c='b',linestyle="-")
#一部銘柄
ax.plot(pd.to_datetime(did100.index),did100['Close'],c='r',linestyle="-")


# ax.legend(labels=['Benchmark S&P500','portfolio460',portName,'portfolio100日次R','portfolio月次R'],fontsize=30)

ax.legend(labels=['Benchmark S&P500','portfolio460',portName],fontsize=30)
ax.set_xlabel('date', size=15)
ax.set_ylabel('value', size=15)
ax.set_title('Benchmark vs. Replication Portfolio', fontsize=30)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=30)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))

#
#TE計算
#

portDaily = did.pct_change()
portDaily = portDaily.fillna(0)

portDaily100 = did100.pct_change()
portDaily100 = portDaily100.fillna(0)

ax = fig.add_subplot(spec[1, 0])
ax.plot(pd.to_datetime(Benchmark.index),((Benchmarkd['Close']-portDaily['Close'])**2)**0.5, c='b')
ax.legend(labels=['portfolio460'],fontsize=20)

ax.set_xlabel('date', size=15)
ax.set_ylabel('tracking error', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=30)

ax = fig.add_subplot(spec[2, 0])
ax.plot(pd.to_datetime(Benchmark.index),((Benchmarkd['Close']-portDaily100['Close'])**2)**0.5, c='r')
ax.legend(labels=[portName],fontsize=20)

ax.set_xlabel('date', size=15)
ax.set_ylabel('tracking error', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=30)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))

fig.savefig('84mon-based.png')
# Out:
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'WFC', 'JPM', 'PFE', 'AMZN', 'CVX', 'JNJ', 'KO', 'T', 'UNH', 'MA', 'BAC', 'INTC', 'HD', 'DIS', 'PG', 'IBM', 'SLB', 'GS', 'GE', 'CSCO', 'CMCSA', 'ADP', 'ACN', 'ABBV', 'PM', 'LMT', 'MDT', 'BA', 'AMGN', 'UNP', 'DD', 'GILD', 'COST', 'MMM', 'V', 'META', 'EOG', 'AXP', 'VZ', 'TROW', 'MO', 'C', 'ABT', 'EMR', 'HON', 'PEP', 'MRK', 'CVS', 'MCD', 'SO', 'MDLZ', 'BMY', 'PGR', 'CAT', 'ADBE', 'ORCL']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'WFC', 'JPM', 'PFE', 'AMZN', 'CVX', 'JNJ', 'KO', 'UNH', 'INTC', 'T', 'MA', 'DIS', 'BAC', 'HD', 'IBM', 'PG', 'SLB', 'CSCO', 'GE', 'CMCSA', 'GS', 'ADP', 'VZ', 'ACN', 'C', 'UNP', 'BA', 'ABBV', 'LMT', 'AMGN', 'DD', 'PM', 'MDT', 'V', 'ABT', 'GILD', 'COST', 'META', 'TROW', 'EMR', 'PEP', 'AXP', 'HON', 'MRK', 'MMM', 'EOG', 'MO', 'MCD', 'BMY', 'MAR', 'CAT', 'ADBE', 'CVS', 'L', 'SO', 'PGR']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'WFC', 'PFE', 'JPM', 'AMZN', 'CVX', 'JNJ', 'UNH', 'KO', 'T', 'INTC', 'DIS', 'MA', 'HD', 'BAC', 'PG', 'IBM', 'SLB', 'CSCO', 'CMCSA', 'GE', 'ADP', 'GS', 'C', 'VZ', 'ACN', 'UNP', 'ABBV', 'LMT', 'BA', 'DD', 'MDT', 'AMGN', 'PM', 'ABT', 'COST', 'V', 'GILD', 'PEP', 'AXP', 'META', 'TROW', 'EOG', 'MCD', 'EMR', 'MO', 'HON', 'CVS', 'MRK', 'MMM', 'ADBE', 'MDLZ', 'SO', 'CAT', 'BMY', 'PNC', 'PGR']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'WFC', 'JPM', 'AMZN', 'PFE', 'CVX', 'JNJ', 'UNH', 'KO', 'DIS', 'MA', 'HD', 'INTC', 'T', 'PG', 'BAC', 'SLB', 'IBM', 'CSCO', 'CMCSA', 'ADP', 'VZ', 'GE', 'GS', 'UNP', 'MDT', 'LMT', 'C', 'BA', 'ACN', 'ABBV', 'DD', 'AMGN', 'ABT', 'COST', 'PM', 'META', 'GILD', 'AXP', 'TROW', 'V', 'PEP', 'MO', 'MCD', 'MRK', 'CVS', 'EOG', 'EMR', 'BMY', 'ADBE', 'MDLZ', 'HON', 'PNC', 'CAT', 'SO', 'PGR', 'SPG']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JPM', 'WFC', 'AMZN', 'PFE', 'CVX', 'JNJ', 'DIS', 'UNH', 'KO', 'HD', 'MA', 'INTC', 'T', 'BAC', 'PG', 'CSCO', 'IBM', 'SLB', 'CMCSA', 'ADP', 'GS', 'GE', 'UNP', 'VZ', 'LMT', 'ABBV', 'BA', 'AMGN', 'ACN', 'MDT', 'DD', 'ABT', 'C', 'PM', 'META', 'AXP', 'GILD', 'COST', 'TROW', 'MCD', 'PEP', 'EOG', 'EMR', 'V', 'PNC', 'MRK', 'CVS', 'HON', 'SPG', 'MDLZ', 'SO', 'CAT', 'MO', 'ADBE', 'BMY', 'PGR']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JPM', 'WFC', 'PFE', 'AMZN', 'JNJ', 'CVX', 'DIS', 'KO', 'UNH', 'HD', 'T', 'INTC', 'BAC', 'MA', 'PG', 'CSCO', 'IBM', 'SLB', 'ADP', 'GS', 'CMCSA', 'BA', 'GE', 'UNP', 'LMT', 'AMGN', 'VZ', 'MDT', 'ACN', 'ABBV', 'C', 'META', 'DD', 'ABT', 'PM', 'AXP', 'COST', 'TROW', 'EOG', 'MCD', 'GILD', 'MRK', 'CVS', 'V', 'EMR', 'PEP', 'PNC', 'HON', 'BMY', 'ADBE', 'MDLZ', 'SPG', 'CAT', 'SO', 'MO', 'WMT']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JPM', 'PFE', 'WFC', 'JNJ', 'AMZN', 'CVX', 'UNH', 'DIS', 'KO', 'MA', 'HD', 'T', 'INTC', 'PG', 'BAC', 'CSCO', 'ADP', 'SLB', 'IBM', 'CMCSA', 'GS', 'BA', 'UNP', 'GE', 'MDT', 'ACN', 'ABBV', 'META', 'ABT', 'TROW', 'AXP', 'VZ', 'PEP', 'EMR', 'AMGN', 'COST', 'LMT', 'C', 'MRK', 'EOG', 'GILD', 'MCD', 'PM', 'CAT', 'CVS', 'V', 'ADBE', 'PNC', 'SPG', 'MDLZ', 'BMY', 'HON', 'WMT', 'MO', 'DHR', 'SO']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'WFC', 'AMZN', 'UNH', 'CVX', 'DIS', 'MA', 'HD', 'KO', 'T', 'PG', 'INTC', 'BAC', 'CSCO', 'GS', 'SLB', 'CMCSA', 'ADP', 'IBM', 'BA', 'ACN', 'GE', 'MDT', 'ABBV', 'META', 'UNP', 'TROW', 'AXP', 'VZ', 'EMR', 'PEP', 'ABT', 'LMT', 'C', 'GILD', 'MRK', 'COST', 'EOG', 'MCD', 'CAT', 'AMGN', 'PNC', 'ADBE', 'GOOG', 'V', 'WMT', 'CVS', 'BMY', 'PM', 'MDLZ', 'SPG', 'MO', 'PGR', 'DHR']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'AMZN', 'WFC', 'CVX', 'UNH', 'DIS', 'MA', 'KO', 'T', 'HD', 'PG', 'INTC', 'BAC', 'GS', 'CMCSA', 'CSCO', 'ADP', 'BA', 'SLB', 'IBM', 'ACN', 'MDT', 'PEP', 'AXP', 'META', 'ABBV', 'TROW', 'VZ', 'UNP', 'EMR', 'COST', 'LMT', 'GE', 'MRK', 'GILD', 'C', 'ABT', 'EOG', 'WMT', 'AMGN', 'MCD', 'GOOG', 'CAT', 'ADBE', 'CVS', 'PNC', 'V', 'BMY', 'MDLZ', 'PM', 'MO', 'PGR', 'ORCL', 'BAX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'AMZN', 'PFE', 'CVX', 'JNJ', 'WFC', 'DIS', 'UNH', 'MA', 'KO', 'PG', 'HD', 'T', 'BAC', 'INTC', 'GS', 'CMCSA', 'ADP', 'ACN', 'BA', 'CSCO', 'AXP', 'IBM', 'SLB', 'MRK', 'ABBV', 'META', 'UNP', 'VZ', 'PEP', 'MDT', 'COST', 'TROW', 'GE', 'GOOG', 'AMGN', 'C', 'MCD', 'WMT', 'EOG', 'EMR', 'CVS', 'ABT', 'GILD', 'LMT', 'WEC', 'ADBE', 'CAT', 'BMY', 'PM', 'DHR', 'V', 'BAX', 'MDLZ', 'MO', 'PNC']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'AMZN', 'PFE', 'JNJ', 'CVX', 'MA', 'UNH', 'DIS', 'WFC', 'KO', 'T', 'HD', 'BAC', 'PG', 'INTC', 'GS', 'CMCSA', 'ACN', 'ADP', 'BA', 'CSCO', 'IBM', 'AXP', 'MRK', 'SLB', 'ABBV', 'MDT', 'META', 'TROW', 'MCD', 'COST', 'GE', 'UNP', 'PEP', 'GOOG', 'VZ', 'EMR', 'AMGN', 'GILD', 'C', 'EOG', 'ABT', 'WMT', 'LMT', 'CVS', 'WEC', 'PM', 'ADBE', 'BMY', 'V', 'CAT', 'PNC', 'DHR', 'MDLZ', 'TRV', 'RTX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'AMZN', 'CVX', 'JNJ', 'DIS', 'MA', 'UNH', 'WFC', 'KO', 'HD', 'T', 'PG', 'BAC', 'INTC', 'GS', 'ACN', 'CMCSA', 'ADP', 'BA', 'CSCO', 'IBM', 'MRK', 'AXP', 'ABBV', 'TROW', 'GOOG', 'META', 'MDT', 'SLB', 'MCD', 'UNP', 'COST', 'GE', 'VZ', 'PEP', 'EMR', 'AMGN', 'GILD', 'C', 'WMT', 'LMT', 'ABT', 'EOG', 'CVS', 'PM', 'WEC', 'ADBE', 'V', 'CAT', 'BMY', 'DHR', 'MDLZ', 'PNC', 'TRV', 'SYK']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'AMZN', 'CVX', 'JNJ', 'DIS', 'MA', 'UNH', 'WFC', 'KO', 'HD', 'T', 'PG', 'INTC', 'BAC', 'CMCSA', 'GS', 'ACN', 'ADP', 'IBM', 'BA', 'CSCO', 'AXP', 'MRK', 'META', 'ABBV', 'TROW', 'MDT', 'SLB', 'GOOG', 'C', 'MCD', 'VZ', 'UNP', 'GE', 'COST', 'EMR', 'PM', 'AMGN', 'WMT', 'ABT', 'GILD', 'PEP', 'LMT', 'CVS', 'WEC', 'EOG', 'ADBE', 'V', 'CAT', 'BMY', 'MDLZ', 'PNC', 'TRV', 'DHR', 'RTX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'AMZN', 'JNJ', 'PFE', 'CVX', 'DIS', 'MA', 'WFC', 'UNH', 'HD', 'KO', 'T', 'INTC', 'BAC', 'PG', 'GS', 'ACN', 'CMCSA', 'TROW', 'IBM', 'AXP', 'CSCO', 'MRK', 'ADP', 'BA', 'MDT', 'META', 'ABBV', 'VZ', 'MCD', 'GE', 'UNP', 'COST', 'EMR', 'GILD', 'SLB', 'LMT', 'PM', 'GOOG', 'WMT', 'AMGN', 'ABT', 'PEP', 'C', 'CVS', 'EOG', 'ADBE', 'WEC', 'BMY', 'V', 'CAT', 'PNC', 'MDLZ', 'RTX', 'BAX', 'SYK']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'AMZN', 'PFE', 'JNJ', 'CVX', 'DIS', 'UNH', 'WFC', 'MA', 'HD', 'KO', 'T', 'PG', 'BAC', 'INTC', 'MRK', 'GS', 'TROW', 'ACN', 'CMCSA', 'BA', 'UNP', 'IBM', 'MDT', 'CSCO', 'META', 'ABBV', 'VZ', 'SLB', 'GE', 'AXP', 'COST', 'ADP', 'MCD', 'GILD', 'PM', 'WMT', 'GOOG', 'EOG', 'WEC', 'LMT', 'V', 'C', 'CVS', 'EMR', 'ABT', 'AMGN', 'ADBE', 'BMY', 'PEP', 'CAT', 'MDLZ', 'MS', 'MAR', 'RTX', 'BAX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'PFE', 'AMZN', 'JPM', 'JNJ', 'HD', 'KO', 'UNH', 'DIS', 'PG', 'WFC', 'MA', 'BAC', 'T', 'INTC', 'CVX', 'MRK', 'CMCSA', 'VZ', 'CSCO', 'WMT', 'TROW', 'ED', 'META', 'COST', 'ADP', 'GOOG', 'UNP', 'IBM', 'EOG', 'ACN', 'ABBV', 'GS', 'GILD', 'PM', 'GE', 'CAT', 'LIN', 'CVS', 'TRV', 'ABT', 'ADBE', 'LMT', 'BAX', 'MS', 'DHR', 'V', 'SLB', 'BMY', 'AMGN', 'MDT', 'MDLZ', 'MAR', 'C', 'MCD', 'AXP', 'ORCL']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'AMZN', 'JNJ', 'HD', 'UNH', 'PFE', 'PG', 'JPM', 'WFC', 'INTC', 'T', 'ABT', 'DIS', 'KO', 'CVX', 'CMCSA', 'MRK', 'MMC', 'ADP', 'BAC', 'VZ', 'META', 'WMT', 'UNP', 'COST', 'MS', 'ADBE', 'GS', 'MA', 'CSCO', 'DHR', 'MDLZ', 'IBM', 'CAT', 'MCD', 'CVS', 'ABBV', 'ACN', 'GOOG', 'ED', 'LIN', 'BAX', 'SLB', 'V', 'LMT', 'BMY', 'GE', 'GILD', 'AMGN', 'PM', 'BK', 'EOG', 'TROW', 'QCOM', 'ANSS', 'CL', 'PEP']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'AMZN', 'JNJ', 'PFE', 'HD', 'UNH', 'JPM', 'INTC', 'MMC', 'T', 'PG', 'DIS', 'UNP', 'CVX', 'KO', 'VZ', 'ABT', 'CMCSA', 'MRK', 'BAC', 'WFC', 'WMT', 'COST', 'ADP', 'ADBE', 'META', 'MS', 'GS', 'BLK', 'DHR', 'CSCO', 'MCD', 'ABBV', 'MA', 'CVS', 'IBM', 'MDLZ', 'BAX', 'PEP', 'V', 'EOG', 'LIN', 'BMY', 'CAT', 'ACN', 'AMGN', 'CL', 'BK', 'GE', 'TROW', 'GOOG', 'QCOM', 'PM', 'GILD', 'ANSS', 'TMO', 'SLB']
# ['AAPL', 'MSFT', 'GOOGL', 'JNJ', 'XOM', 'AMZN', 'UNH', 'PFE', 'JPM', 'HD', 'INTC', 'MMC', 'T', 'DIS', 'CVX', 'PG', 'KO', 'UNP', 'VZ', 'ABT', 'CMCSA', 'MRK', 'WMT', 'BAC', 'GS', 'COST', 'META', 'ADBE', 'BLK', 'DHR', 'MS', 'WFC', 'ADP', 'ABBV', 'MCD', 'MA', 'CSCO', 'PEP', 'LIN', 'V', 'CVS', 'MDLZ', 'IBM', 'CL', 'EOG', 'AMGN', 'ACN', 'BAX', 'BMY', 'BK', 'CAT', 'TROW', 'ARE', 'NKE', 'GILD', 'TMO', 'ANSS', 'GE', 'QCOM', 'SLB']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'XOM', 'JNJ', 'PFE', 'UNH', 'DIS', 'T', 'HD', 'JPM', 'BAC', 'GS', 'MMC', 'PG', 'INTC', 'MRK', 'COST', 'UNP', 'META', 'WMT', 'KO', 'CMCSA', 'CVX', 'ADBE', 'VZ', 'MA', 'ABT', 'MCD', 'UPS', 'CSCO', 'ABBV', 'AMGN', 'PEP', 'LIN', 'BLK', 'DHR', 'EOG', 'IBM', 'TROW', 'ACN', 'MS', 'CVS', 'WFC', 'ARE', 'BAX', 'TMO', 'QCOM', 'MDLZ', 'BMY', 'ADP', 'MET', 'LLY', 'SLB', 'TECH', 'BK', 'CME', 'CL', 'FE']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'XOM', 'JNJ', 'PFE', 'UNH', 'DIS', 'T', 'HD', 'GS', 'ADBE', 'BAC', 'MMC', 'JPM', 'INTC', 'MRK', 'COST', 'META', 'CVX', 'PG', 'CMCSA', 'KO', 'VZ', 'UNP', 'MCD', 'ABT', 'WMT', 'AMGN', 'LIN', 'DHR', 'PEP', 'MA', 'EOG', 'ABBV', 'ACN', 'SNPS', 'UPS', 'BLK', 'IBM', 'TROW', 'CSCO', 'MDLZ', 'MS', 'WFC', 'CVS', 'GOOG', 'QCOM', 'BMY', 'CRM', 'CME', 'TMO', 'ARE', 'BAX', 'LLY', 'PNC', 'FE', 'TECH', 'BA']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'PFE', 'XOM', 'UNH', 'DIS', 'T', 'ADBE', 'HD', 'CVX', 'JPM', 'GS', 'WMT', 'BAC', 'CMCSA', 'COST', 'META', 'MMC', 'PG', 'UNP', 'VZ', 'MRK', 'SNPS', 'INTC', 'KO', 'AMGN', 'LIN', 'UPS', 'ABT', 'PEP', 'EOG', 'DHR', 'IBM', 'BLK', 'MCD', 'ABBV', 'TROW', 'MA', 'ACN', 'MS', 'WEC', 'QCOM', 'TMO', 'MDLZ', 'WFC', 'NEE', 'ANSS', 'BMY', 'CSCO', 'ORCL', 'CRM', 'BA', 'LMT', 'GOOG', 'EL', 'TECH', 'CVS']
# ['AAPL', 'MSFT', 'AMZN', 'JNJ', 'GOOGL', 'PFE', 'UNH', 'XOM', 'DIS', 'T', 'ADBE', 'CMCSA', 'HD', 'GS', 'WMT', 'VZ', 'CVX', 'JPM', 'PG', 'META', 'UNP', 'PEP', 'COST', 'BAC', 'SNPS', 'UPS', 'MRK', 'GOOG', 'AMGN', 'EOG', 'KO', 'LIN', 'MMC', 'DHR', 'ABT', 'ACN', 'INTC', 'BLK', 'ANSS', 'WFC', 'IBM', 'QCOM', 'MDLZ', 'MA', 'ABBV', 'MCD', 'NEE', 'BMY', 'TROW', 'C', 'BA', 'TMO', 'ORCL', 'CRM', 'EL', 'MS', 'LMT', 'INTU', 'ARE', 'V']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'XOM', 'PFE', 'DIS', 'T', 'PG', 'HD', 'ADBE', 'VZ', 'GS', 'CMCSA', 'JPM', 'SNPS', 'UNP', 'META', 'WMT', 'COST', 'BAC', 'MRK', 'CVX', 'UPS', 'DHR', 'PEP', 'LIN', 'EOG', 'ABT', 'TMO', 'AMGN', 'ACN', 'INTC', 'WFC', 'QCOM', 'KO', 'BLK', 'MMC', 'MCD', 'TROW', 'LMT', 'MDLZ', 'MA', 'IBM', 'C', 'NEE', 'BIIB', 'GOOG', 'BMY', 'EL', 'ANSS', 'ABBV', 'ORCL', 'INTU', 'BA', 'CRM', 'PLD', 'LOW']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'UNH', 'JNJ', 'XOM', 'PFE', 'PG', 'DIS', 'HD', 'VZ', 'CMCSA', 'ADBE', 'JPM', 'SNPS', 'GS', 'T', 'META', 'UNP', 'BAC', 'COST', 'WMT', 'CVX', 'MRK', 'LIN', 'DHR', 'TMO', 'ABT', 'UPS', 'PEP', 'EOG', 'BLK', 'INTC', 'AMGN', 'QCOM', 'MCD', 'ACN', 'MMC', 'WFC', 'KO', 'MA', 'MDLZ', 'LMT', 'TROW', 'EL', 'IBM', 'BMY', 'BIIB', 'ABBV', 'C', 'NEE', 'ANSS', 'ORCL', 'BA', 'XEL', 'INTU', 'GOOG', 'PLD', 'CRM']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'XOM', 'CMCSA', 'JPM', 'ADBE', 'DIS', 'HD', 'T', 'PG', 'SNPS', 'META', 'COST', 'VZ', 'CVX', 'UNP', 'KO', 'BAC', 'WMT', 'GS', 'ABT', 'LIN', 'EOG', 'MRK', 'MCD', 'BLK', 'TMO', 'UPS', 'AMGN', 'INTC', 'ACN', 'QCOM', 'MA', 'PEP', 'TROW', 'EL', 'WFC', 'ORCL', 'XEL', 'PLD', 'DHR', 'ANSS', 'MDLZ', 'ABBV', 'BA', 'MMC', 'IBM', 'ARE', 'DOV', 'BIIB', 'LMT', 'NEE', 'BMY', 'C', 'INTU']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'CMCSA', 'XOM', 'JPM', 'ADBE', 'SNPS', 'T', 'DIS', 'HD', 'PG', 'META', 'COST', 'CVX', 'VZ', 'UNP', 'KO', 'WMT', 'BAC', 'GS', 'LIN', 'BLK', 'INTC', 'AMGN', 'TMO', 'UPS', 'ANSS', 'PEP', 'EOG', 'ABT', 'ACN', 'MCD', 'MRK', 'QCOM', 'MA', 'TROW', 'DHR', 'XEL', 'EL', 'WFC', 'BA', 'PLD', 'ABBV', 'IBM', 'MDLZ', 'NEE', 'INTU', 'ORCL', 'DOV', 'BMY', 'C', 'LMT', 'BIIB', 'TXN', 'ARE']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'JPM', 'CMCSA', 'XOM', 'ADBE', 'SNPS', 'DIS', 'HD', 'PG', 'T', 'COST', 'CVX', 'META', 'WMT', 'VZ', 'KO', 'UNP', 'GS', 'LIN', 'BLK', 'INTC', 'NEE', 'MCD', 'TMO', 'ANSS', 'ABT', 'PEP', 'EOG', 'ACN', 'AMGN', 'UPS', 'BAC', 'MRK', 'QCOM', 'EL', 'MA', 'INTU', 'TROW', 'DHR', 'BA', 'PLD', 'WFC', 'ABBV', 'MDLZ', 'IBM', 'DOV', 'C', 'BMY', 'ICE', 'BIIB', 'ARE', 'FAST', 'ORCL', 'LMT']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'JPM', 'CMCSA', 'XOM', 'SNPS', 'ADBE', 'HD', 'DIS', 'PG', 'COST', 'CVX', 'META', 'T', 'VZ', 'WMT', 'UNP', 'BLK', 'LIN', 'KO', 'TMO', 'INTC', 'GS', 'ANSS', 'NEE', 'ABT', 'PEP', 'MCD', 'AMGN', 'EOG', 'QCOM', 'MRK', 'BAC', 'INTU', 'ACN', 'TROW', 'UPS', 'DHR', 'EL', 'MA', 'BA', 'ABBV', 'PLD', 'PCAR', 'ICE', 'MDLZ', 'WFC', 'IBM', 'BMY', 'ORCL', 'DOV', 'C', 'LMT', 'BIIB', 'ARE']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'UNH', 'JNJ', 'JPM', 'PFE', 'CMCSA', 'SNPS', 'XOM', 'ADBE', 'COST', 'HD', 'DIS', 'META', 'CVX', 'PG', 'T', 'UNP', 'VZ', 'WMT', 'BLK', 'NEE', 'KO', 'TMO', 'LIN', 'INTC', 'GS', 'ABT', 'PEP', 'QCOM', 'EL', 'ANSS', 'MCD', 'ACN', 'AMGN', 'EOG', 'BAC', 'DHR', 'MRK', 'MA', 'INTU', 'BA', 'UPS', 'ICE', 'ABBV', 'PCAR', 'DOV', 'TROW', 'PLD', 'MET', 'ARE', 'MDLZ', 'LMT', 'CB', 'ORCL', 'WFC', 'IBM', 'BIIB']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JPM', 'JNJ', 'UNH', 'PFE', 'SNPS', 'XOM', 'CMCSA', 'ADBE', 'COST', 'HD', 'DIS', 'CVX', 'META', 'T', 'PG', 'UNP', 'VZ', 'NEE', 'WMT', 'BLK', 'KO', 'TMO', 'LIN', 'INTC', 'GS', 'PEP', 'QCOM', 'DHR', 'EL', 'ABT', 'ANSS', 'MCD', 'AMGN', 'ACN', 'EOG', 'BAC', 'MRK', 'MA', 'ICE', 'INTU', 'BA', 'UPS', 'TROW', 'PCAR', 'ABBV', 'DOV', 'WFC', 'MDLZ', 'LMT', 'CB', 'MET', 'ORCL', 'PLD', 'IBM', 'ARE', 'BMY']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JPM', 'JNJ', 'UNH', 'PFE', 'XOM', 'SNPS', 'CMCSA', 'ADBE', 'DIS', 'HD', 'CVX', 'META', 'COST', 'T', 'UNP', 'WMT', 'VZ', 'NEE', 'PG', 'BLK', 'KO', 'TMO', 'LIN', 'GS', 'PEP', 'INTC', 'QCOM', 'EL', 'MCD', 'ABT', 'ANSS', 'DHR', 'ACN', 'AMGN', 'MA', 'EOG', 'MRK', 'BAC', 'ICE', 'BA', 'INTU', 'UPS', 'TROW', 'PCAR', 'ABBV', 'DOV', 'CB', 'MDLZ', 'PLD', 'ORCL', 'BMY', 'MET', 'WFC', 'BIIB', 'IBM', 'LMT']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JPM', 'JNJ', 'UNH', 'PFE', 'XOM', 'CMCSA', 'SNPS', 'DIS', 'ADBE', 'HD', 'COST', 'META', 'T', 'CVX', 'PG', 'VZ', 'BLK', 'UNP', 'WMT', 'KO', 'NEE', 'LIN', 'TMO', 'GS', 'PEP', 'INTC', 'QCOM', 'EL', 'MCD', 'ABT', 'ANSS', 'ACN', 'EOG', 'DHR', 'MA', 'AMGN', 'BAC', 'MRK', 'INTU', 'ICE', 'BA', 'TROW', 'UPS', 'ABBV', 'DOV', 'PCAR', 'CB', 'PLD', 'ORCL', 'MDLZ', 'IBM', 'ARE', 'BMY', 'LMT', 'BIIB', 'MET']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JPM', 'JNJ', 'UNH', 'PFE', 'XOM', 'CMCSA', 'SNPS', 'DIS', 'COST', 'ADBE', 'META', 'CVX', 'HD', 'T', 'VZ', 'PG', 'UNP', 'LIN', 'NEE', 'WMT', 'KO', 'BLK', 'TMO', 'GS', 'PEP', 'EL', 'QCOM', 'ANSS', 'INTC', 'ACN', 'MCD', 'ABT', 'BAC', 'DHR', 'TROW', 'MA', 'EOG', 'INTU', 'ICE', 'AMGN', 'BA', 'MRK', 'ABBV', 'UPS', 'DOV', 'PCAR', 'CB', 'ARE', 'PLD', 'LMT', 'BMY', 'MDLZ', 'IBM', 'BIIB', 'ORCL', 'TECH']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'PFE', 'XOM', 'COST', 'DIS', 'SNPS', 'CMCSA', 'HD', 'META', 'ADBE', 'CVX', 'T', 'PG', 'VZ', 'LIN', 'NEE', 'KO', 'UNP', 'GS', 'WMT', 'TMO', 'BLK', 'INTC', 'MCD', 'PEP', 'EL', 'ANSS', 'ACN', 'QCOM', 'ABT', 'MA', 'INTU', 'BAC', 'DHR', 'EOG', 'ICE', 'AMGN', 'TROW', 'BA', 'DOV', 'MRK', 'ABBV', 'PLD', 'UPS', 'WFC', 'PCAR', 'ARE', 'MDLZ', 'LMT', 'ORCL', 'BIIB', 'BMY', 'CB', 'TECH']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'PFE', 'XOM', 'DIS', 'HD', 'COST', 'SNPS', 'ADBE', 'CMCSA', 'META', 'CVX', 'NEE', 'VZ', 'LIN', 'T', 'PG', 'KO', 'UNP', 'WMT', 'TMO', 'GS', 'MCD', 'INTC', 'PEP', 'BLK', 'QCOM', 'ANSS', 'EL', 'ACN', 'INTU', 'ABT', 'TROW', 'BAC', 'ICE', 'AMGN', 'EOG', 'DHR', 'MA', 'BA', 'MRK', 'DOV', 'ABBV', 'WFC', 'ARE', 'PLD', 'ORCL', 'UPS', 'LMT', 'IBM', 'NVDA', 'TECH', 'MDLZ', 'BIIB', 'NDAQ']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'ADBE', 'COST', 'XOM', 'DIS', 'HD', 'PFE', 'SNPS', 'NEE', 'META', 'CVX', 'LIN', 'VZ', 'CMCSA', 'PG', 'T', 'KO', 'TROW', 'MCD', 'UNP', 'PEP', 'INTC', 'WMT', 'QCOM', 'GS', 'EL', 'BLK', 'TMO', 'INTU', 'ANSS', 'ARE', 'AMGN', 'ABT', 'MRK', 'ICE', 'BA', 'DHR', 'BAC', 'UPS', 'WFC', 'ACN', 'EOG', 'LLY', 'ORCL', 'DOV', 'NVDA', 'ABBV', 'IBM', 'TECH', 'LMT', 'IDXX', 'PCAR', 'NDAQ', 'PLD']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'XOM', 'HD', 'PFE', 'SNPS', 'VZ', 'META', 'CMCSA', 'NEE', 'CVX', 'LIN', 'KO', 'PG', 'PEP', 'TROW', 'MCD', 'GS', 'T', 'BLK', 'INTC', 'QCOM', 'EL', 'WMT', 'ARE', 'TMO', 'INTU', 'UNP', 'WFC', 'DHR', 'AMGN', 'ANSS', 'MRK', 'ABT', 'BA', 'ICE', 'ACN', 'NVDA', 'DOV', 'LLY', 'ORCL', 'TECH', 'EOG', 'ABBV', 'UPS', 'IDXX', 'LMT', 'IBM', 'V', 'BAC', 'PCAR', 'BIIB']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'XOM', 'SNPS', 'HD', 'META', 'NEE', 'CMCSA', 'PFE', 'VZ', 'PG', 'CVX', 'KO', 'LIN', 'TROW', 'QCOM', 'MCD', 'T', 'EL', 'GS', 'PEP', 'BLK', 'INTC', 'ARE', 'WFC', 'UNP', 'INTU', 'MRK', 'TMO', 'WMT', 'AMGN', 'ANSS', 'ACN', 'DHR', 'DOV', 'ORCL', 'ABT', 'NVDA', 'ICE', 'LLY', 'BA', 'EOG', 'TECH', 'BAC', 'V', 'ABBV', 'DD', 'IBM', 'UPS', 'PCAR', 'IDXX', 'BIIB']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'UNH', 'JNJ', 'JPM', 'COST', 'DIS', 'ADBE', 'SNPS', 'META', 'PFE', 'LIN', 'XOM', 'CMCSA', 'PG', 'HD', 'NEE', 'VZ', 'MCD', 'TROW', 'CVX', 'KO', 'QCOM', 'T', 'WFC', 'EL', 'PEP', 'BLK', 'INTC', 'INTU', 'GS', 'ARE', 'TMO', 'MRK', 'UNP', 'DHR', 'WMT', 'AMGN', 'DOV', 'ANSS', 'ORCL', 'ABT', 'ACN', 'LLY', 'NVDA', 'BA', 'BAC', 'EOG', 'ICE', 'PCAR', 'V', 'TECH', 'DD', 'UPS', 'ABBV', 'IDXX', 'BIIB', 'IBM']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'ADBE', 'SNPS', 'XOM', 'PFE', 'META', 'LIN', 'CMCSA', 'HD', 'VZ', 'TROW', 'PG', 'KO', 'QCOM', 'NEE', 'MCD', 'CVX', 'EL', 'T', 'WFC', 'BLK', 'PEP', 'INTC', 'INTU', 'TMO', 'GS', 'ARE', 'UNP', 'MRK', 'WMT', 'ACN', 'ANSS', 'DHR', 'ABT', 'AMGN', 'ORCL', 'NVDA', 'BAC', 'DOV', 'V', 'LLY', 'BA', 'EOG', 'PCAR', 'ICE', 'DD', 'TECH', 'UPS', 'BIIB', 'IDXX', 'ABBV', 'PNC']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'UNH', 'JNJ', 'JPM', 'DIS', 'COST', 'ADBE', 'XOM', 'META', 'SNPS', 'CMCSA', 'LIN', 'PFE', 'TROW', 'PG', 'NEE', 'VZ', 'QCOM', 'HD', 'EL', 'WFC', 'CVX', 'MCD', 'PEP', 'KO', 'INTU', 'BLK', 'T', 'TMO', 'INTC', 'UNP', 'ARE', 'MRK', 'GS', 'ABT', 'DHR', 'ANSS', 'ACN', 'BAC', 'AMGN', 'ORCL', 'V', 'NVDA', 'BA', 'WMT', 'LLY', 'EOG', 'DOV', 'PCAR', 'DD', 'ICE', 'TECH', 'UPS', 'BIIB', 'ABBV', 'PNC', 'BMY']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'ADBE', 'XOM', 'META', 'CMCSA', 'SNPS', 'TROW', 'PFE', 'LIN', 'PG', 'VZ', 'NEE', 'QCOM', 'PEP', 'CVX', 'WFC', 'HD', 'MCD', 'EL', 'INTU', 'T', 'KO', 'TMO', 'BLK', 'INTC', 'ACN', 'ABT', 'MRK', 'ARE', 'BAC', 'UNP', 'DHR', 'ANSS', 'NVDA', 'GS', 'AMGN', 'ORCL', 'WMT', 'LLY', 'PCAR', 'V', 'BA', 'DOV', 'EOG', 'ICE', 'DD', 'TECH', 'BIIB', 'NKE', 'MMC', 'UPS', 'CRM']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'ADBE', 'XOM', 'META', 'TROW', 'NEE', 'SNPS', 'PFE', 'VZ', 'CMCSA', 'CVX', 'LIN', 'PEP', 'QCOM', 'WFC', 'EL', 'PG', 'T', 'INTU', 'HD', 'MCD', 'BLK', 'TMO', 'KO', 'MRK', 'ACN', 'WMT', 'ABT', 'INTC', 'DHR', 'BAC', 'ARE', 'UNP', 'ANSS', 'NVDA', 'ORCL', 'AMGN', 'LLY', 'GS', 'V', 'BA', 'PCAR', 'EOG', 'DOV', 'ICE', 'DD', 'BIIB', 'TECH', 'UPS', 'NKE', 'MMC', 'LMT']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'XOM', 'META', 'NEE', 'PFE', 'TROW', 'CMCSA', 'LIN', 'CVX', 'PEP', 'VZ', 'SNPS', 'QCOM', 'WFC', 'PG', 'EL', 'T', 'INTU', 'MCD', 'HD', 'TMO', 'BLK', 'KO', 'ACN', 'MRK', 'ABT', 'DHR', 'INTC', 'BAC', 'ANSS', 'WMT', 'UNP', 'NVDA', 'ORCL', 'ARE', 'LLY', 'GS', 'AMGN', 'PCAR', 'ICE', 'V', 'BA', 'DOV', 'EOG', 'DD', 'TECH', 'BIIB', 'MMC', 'UPS', 'NKE', 'LMT']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'XOM', 'META', 'PFE', 'LIN', 'NEE', 'CMCSA', 'CVX', 'TROW', 'PEP', 'SNPS', 'VZ', 'QCOM', 'PG', 'T', 'EL', 'WFC', 'INTU', 'TMO', 'BLK', 'MCD', 'KO', 'ACN', 'HD', 'MRK', 'INTC', 'ABT', 'DHR', 'WMT', 'ANSS', 'BAC', 'NVDA', 'ORCL', 'UNP', 'ARE', 'GS', 'AMGN', 'LLY', 'PCAR', 'ICE', 'V', 'BA', 'DD', 'DOV', 'EOG', 'LMT', 'UPS', 'TECH', 'MMC', 'NKE', 'CRM']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'COST', 'DIS', 'JPM', 'XOM', 'ADBE', 'META', 'PFE', 'NEE', 'PEP', 'CMCSA', 'LIN', 'TROW', 'CVX', 'VZ', 'PG', 'SNPS', 'QCOM', 'INTU', 'EL', 'TMO', 'WFC', 'T', 'MCD', 'BLK', 'KO', 'ACN', 'MRK', 'HD', 'INTC', 'ABT', 'UNP', 'WMT', 'NVDA', 'ANSS', 'ARE', 'DHR', 'AMGN', 'ORCL', 'BAC', 'GS', 'LLY', 'PCAR', 'BA', 'ICE', 'DD', 'EOG', 'UPS', 'DOV', 'PNC', 'LMT', 'V', 'TECH', 'NKE', 'CVS']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'COST', 'DIS', 'JPM', 'PEP', 'XOM', 'ADBE', 'PFE', 'LIN', 'META', 'CMCSA', 'CVX', 'NEE', 'INTU', 'QCOM', 'VZ', 'SNPS', 'PG', 'EL', 'TMO', 'WFC', 'TROW', 'MCD', 'T', 'BLK', 'MRK', 'KO', 'ACN', 'INTC', 'ABT', 'WMT', 'HD', 'ARE', 'NVDA', 'ANSS', 'ORCL', 'UNP', 'LLY', 'DHR', 'GS', 'PCAR', 'AMGN', 'BAC', 'BA', 'ICE', 'UPS', 'LMT', 'V', 'DOV', 'DD', 'EOG', 'CRM', 'BMY', 'TECH', 'CVS']
